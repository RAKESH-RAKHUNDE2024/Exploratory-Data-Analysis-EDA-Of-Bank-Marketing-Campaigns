# %% [markdown]
# #### 📝 Project:- Exploratory Data Analysis (EDA) On Bank Marketing Dataset
# #### Dataset: Bank-dataset-use-for-marketing.csv
#
# ##### Objective:- Perform A Comprehensive EDA To Understand The Dataset's Structure, Identify Patterns, And Derive Insights That Can Inform Marketing Strategies.

# %% [markdown]
# ### 1) Load The Dataset
#
# #### Question 1) Load The Dataset Into A Pandas DataFrame And Display The First Five Rows.

# %%
import pandas as pd

# Load The Dataset

Banking_Df = pd.read_csv('bank-dataset-use-for-marketing.csv', sep=';')

# Display The First Five Rows

Banking_Df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# ### 2) Data Overview
# #### Question 2) :- Obtain A Summary Of The Dataset, Including The Number Of Rows, Columns, And Data Types Of Each Column.

# %%
# Get Dataset Information

Banking_Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# ### 3) Descriptive Statistics
# #### Question 3) :- Generate Descriptive Statistics For Numerical Columns, Including Count, Mean, Standard Deviation, Min, Max, And Quartiles.

# %%
Banking_Df.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %% [markdown]
# ### 4) Missing Values
# #### Question 4) :- Check For Any Missing Values In The Dataset And Determine The Percentage Of Missing Data For Each Column.

# %%
# Check For Missing Values

missing_data = Banking_Df.isnull().sum() / len(Banking_Df) * 100
missing_data[missing_data > 0]
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ### 5) Duplicate Entries
# #### Question 5) :- Identify And Count Any Duplicate Rows In The Dataset.

# %%
# Check For Duplicate Rows

duplicates = Banking_Df.duplicated().sum()
duplicates
# Out:
# 12

# %% [markdown]
# ### 6) Unique Values In Categorical Columns
# #### Question 6) :- List The Unique Values For Categorical Columns Such As 'job', 'marital', 'education', Etc.

# %%
# List Unique Values In Categorical Columns

categorical_columns = ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']
unique_values = {col:Banking_Df[col].unique() for col in categorical_columns}
unique_values
# Out:
# {'job': array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#         'retired', 'management', 'unemployed', 'self-employed', 'unknown',
#         'entrepreneur', 'student'], dtype=object),
#  'marital': array(['married', 'single', 'divorced', 'unknown'], dtype=object),
#  'education': array(['basic.4y', 'high.school', 'basic.6y', 'basic.9y',
#         'professional.course', 'unknown', 'university.degree',
#         'illiterate'], dtype=object),
#  'default': array(['no', 'unknown', 'yes'], dtype=object),
#  'housing': array(['no', 'yes', 'unknown'], dtype=object),
#  'loan': array(['no', 'yes', 'unknown'], dtype=object),
#  'contact': array(['telephone', 'cellular'], dtype=object),
#  'month': array(['may', 'jun', 'jul', 'aug', 'oct', 'nov', 'dec', 'mar', 'apr',
#         'sep'], dtype=object),
#  'day_of_week': array(['mon', 'tue', 'wed', 'thu', 'fri'], dtype=object),
#  'poutcome': array(['nonexistent', 'failure', 'success'], dtype=object)}

# %% [markdown]
# ### 7) Correlation Analysis
# #### Question 7) :- Compute The Correlation Matrix For Numerical Columns And Visualize It Using A Heatmap.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select numerical columns
numerical_df = Banking_Df.select_dtypes(include=['number'])

# Compute correlation matrix
corr_matrix = numerical_df.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### 8) Outlier Detection
# #### Question 8) :- Detect Outliers In Numerical Columns Using The Interquartile Range (IQR) Method.

# %%
# Define A Function To Detect Outliers

def detect_outliers(Banking_Df, column):
    Q1 = Banking_Df[column].quantile(0.25)
    Q3 = Banking_Df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return Banking_Df[(Banking_Df[column] < lower_bound) | (Banking_Df[column] > upper_bound)]

# Detect Outliers In 'duration' Column
outliers_duration = detect_outliers(Banking_Df, 'duration')
outliers_duration
# Out:
#        age           job   marital            education  default housing loan  \
# 37      52    technician   married             basic.9y       no     yes   no
# 57      45      services   married          high.school  unknown     yes   no
# 61      51   blue-collar   married             basic.9y       no     yes   no
# 75      41   blue-collar  divorced             basic.4y  unknown     yes   no
# 83      49  entrepreneur   married    university.degree  unknown     yes   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 41147   25    technician    single  professional.course       no     yes   no
# 41153   67     housemaid  divorced  professional.course       no     yes   no
# 41160   33        admin.   married    university.degree       no      no   no
# 41164   54        admin.   married  professional.course       no      no   no
# 41166   32        admin.   married    university.degree       no      no   no
#
# ...

# %% [markdown]
# ### 9) Univariate Analysis
#
# #### Question 9) :- Visualize The Distribution Of Numerical Columns Such As 'age', 'duration', And 'campaign' Using Histograms.

# %%
# Plot Histograms For Numerical Columns

numerical_columns = ['age','duration','campaign']
Banking_Df[numerical_columns].hist(bins=20, figsize=(12,8), color='green')
plt.suptitle('Distribution Of Numerical Columns')
plt.show()

# %% [markdown]
# ### 10) Bivariate Analysis
# #### Question 10) :- Analyze The Relationship Between 'duration' And 'y' (Subscription To Term Deposit) Using A Box Plot.

# %%
# Box Plot Of 'duration' By 'y'

plt.figure(figsize=(8,6))
sns.boxplot(x='y', y='duration',data=Banking_Df, color ='red')
plt.title('Duration Vs Subscription')
plt.show()

# %% [markdown]
# ### 11) Pivot Tables
# #### Question 11) :- Create A Pivot Table To Analyze The Average 'duration' Of Calls For Each 'job' Category.

# %%
# Create Pivot Table

pivot_table = Banking_Df.pivot_table(values='duration',index='job',aggfunc='mean')
pivot_table.sort_values(by='duration',ascending=False)
# Out:
#                  duration
# job
# student        283.683429
# retired        273.712209
# blue-collar    264.542360
# self-employed  264.142153
# entrepreneur   263.267857
# services       258.398085
# management     257.058140
# admin.         254.312128
# housemaid      250.454717
# technician     250.232241
# unemployed     249.451677
# unknown        239.675758

# %% [markdown]
# ### 12) Subscription Rate By Job Type
# #### Question 12) :- Calculate The Subscription Rate (Percentage Of 'yes' In 'y') For Each 'job' Category.

# %%
# Calculate Subscription Rate By Job

subscription_rate = Banking_Df.groupby('job')['y'].value_counts(normalize=True).unstack().iloc[:,1] * 100
subscription_rate.sort_values(ascending=False)
# Out:
# job
# student          31.428571
# retired          25.232558
# unemployed       14.201183
# admin.           12.972558
# management       11.217510
# unknown          11.212121
# technician       10.826042
# self-employed    10.485574
# housemaid        10.000000
# entrepreneur      8.516484
# services          8.138070
# blue-collar       6.894316
# Name: yes, dtype: float64

# %% [markdown]
# ### 13) Age Distribution By Subscription Status
# #### Question 13) :- Visualize The Distribution Of 'age' For Clients Who Subscribed ('y' = 'yes') And Did Not Subscribe ('y' = 'no') Using Histograms.

# %%
# Plot Age Distribution By Subscription Status

plt.figure(figsize=(10,6))
sns.histplot(Banking_Df[Banking_Df['y'] == 'yes']['age'], color='green', label='Subscribed', kde=True, stat='density')
sns.histplot(Banking_Df[Banking_Df['y'] == 'no']['age'], color='orange', label='Not Subscribed',kde=True, stat='density')
plt.title('Age Distribution By Subscription Status')
plt.legend()
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# ### 14) Call Duration Analysis
# #### Question 14) :- Determine The Average Call Duration For Each 'contact' Type.

# %%
# Calculate Average Duration By Contact Type

avg_duration_contact =Banking_Df.groupby('contact')['duration'].mean()
avg_duration_contact.sort_values(ascending=False)
# Out:
# contact
# cellular     263.527846
# telephone    249.173823
# Name: duration, dtype: float64

# %% [markdown]
# ### 15. Marketing Campaign Effectiveness
# #### Question 15):- Assess The Effectiveness Of The Marketing Campaign By Comparing The Average Number Of Contacts ('campaign') For Clients Who Subscribed And Did Not Subscribe.

# %%
# Compare Average Number Of Contacts By Subscription Status

avg_contacts_subscription = Banking_Df.groupby('y')['campaign'].mean()
avg_contacts_subscription
# Out:
# y
# no     2.633085
# yes    2.051724
# Name: campaign, dtype: float64
